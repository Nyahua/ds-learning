# %%
import pandas as pd

# %%
pd.read_excel("./批量查询_企业_企查查(85793040).xls", skiprows=1).T
# Out:
#                                                           0
# 企业名称                                               中钢设备有限公司
# 登记状态                                                     存续
# 法定代表人                                                   陆鹏程
# 注册资本                                            400000万元人民币
# 成立日期                                             1990-10-16
# 核准日期                                             2022-08-30
# 所属省份                                                    北京市
# 所属城市                                                    北京市
# 所属区县                                                    海淀区
# 电话                                             010-62688188
# 更多电话                13811636694; 010-62688031; 010-62688038
# 邮箱                                engineering@sinosteel.com
# 更多邮箱                                                      -
# 统一社会信用代码                                 91110000100010804B
# 纳税人识别号                                   91110000100010804B
# ...
